# %% [markdown]
# <a id="top"></a>
#
# # Lab L0310: decide when to reason
#
# ```yaml
# title: "Lab L0310: decide when to reason"
# keywords: when to reason, reasoning cost, latency budget, trade-off, overthinking, lab
# estimated duration: 25
# ```
#
# > **Lesson:** L03. See [objectives.md](../../../../docs/origin/lesson_roadmaps/L03/objectives.md). Solutions: `L0310_lab_solutions.ipynb`. **Pure Python — no API key needed** (you reason about cost, not call a model).
# >
# > **After this lab you can:** classify tasks as reason-vs-answer-cold; estimate the token cost CoT adds; defend a reasoning-depth choice against a latency/cost budget.

# %% [markdown]
# ## Contents
#
# - [1. Setup](#1-setup)
# - [2. Problem 1 — Reason, or answer cold?](#2-problem-1--reason-or-answer-cold)
# - [3. Problem 2 — Estimate what CoT costs](#3-problem-2--estimate-what-cot-costs)
# - [4. Problem 3 — Defend a choice against a budget (written)](#4-problem-3--defend-a-choice-against-a-budget-written)
# - [5. Problem 4 — Two ways reasoning hurts (written)](#5-problem-4--two-ways-reasoning-hurts-written)
# - [6. Self-check](#6-self-check)

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# A rough token estimator and an illustrative output price — the cost half of the trade-off.

# %%
def est_tokens(text: str) -> int:
    """Rough token estimate: ~4 characters per token (L01 rule of thumb for English)."""
    return len(text) // 4


OUTPUT_USD_PER_MTOK = 15.00  # illustrative only; confirm current pricing before teaching
print("setup ready")
# Out:
# setup ready

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 2. Problem 1 — Reason, or answer cold?

# %% [markdown]
# For each task, fill in `"reason"` (CoT/scratchpad helps) or `"cold"` (reasoning is wasted overhead). Recall the help-class: multi-step math, logical deduction, ambiguous classification, multi-constraint generation.

# %%
decision: dict[int, str] = {
    1: "reason",  # multi-step arithmetic check — show the work
    2: "cold",  # zero-shot-easy classification — CoT is pure overhead
    3: "reason",  # multi-constraint deduction — exactly the help-class
    4: "cold",  # short, unambiguous task the model handles in one pass
}
print(decision)
# Out:
# {1: 'reason', 2: 'cold', 3: 'reason', 4: 'cold'}

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 3. Problem 2 — Estimate what CoT costs

# %% [markdown]
# A zero-shot answer to a task is ~`answer_tokens`; the CoT version adds a reasoning preamble of ~`reasoning_tokens` before it. Implement `cot_output_cost` returning the **extra** USD the reasoning preamble costs per call, then compare a few tasks.

# %%
def cot_output_cost(reasoning_tokens: int) -> float:
    """The extra output-token cost the reasoning preamble adds to one call."""
    return reasoning_tokens / 1_000_000 * OUTPUT_USD_PER_MTOK


for label, reasoning in [("short CoT", 80), ("long CoT", 400)]:
    print(f"{label}: extra ${cot_output_cost(reasoning):.5f} per call")
# Out:
# short CoT: extra $0.00120 per call
# long CoT: extra $0.00600 per call

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 4. Problem 3 — Defend a choice against a budget (written)

# %% [markdown]
# For each scenario, write `reason` or `cold` and one phrase justifying it against the stated budget.
#
# | Scenario | reason / cold | Why |
# | --- | --- | --- |
# | Offline nightly batch grading 10k math answers; accuracy matters, latency doesn't | _TODO_ | _TODO_ |
# | Real-time chat autocomplete with a 300ms budget | _TODO_ | _TODO_ |
# | A task where free-form CoT keeps talking the model into a wrong answer | _TODO_ | _TODO_ |
#
# _Write your answers by editing the table above (double-click the cell)._

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 5. Problem 4 — Two ways reasoning hurts (written)

# %% [markdown]
# Name **two** distinct situations where adding explicit reasoning is counterproductive, and say what goes wrong in each.
#
# _Write your answer by editing this cell (double-click)._
#
# 1. _TODO_
# 2. _TODO_

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 6. Self-check

# %% [markdown]
# Compare against `L0310_lab_solutions.ipynb`. Done when your `decision` map matches (reason, cold, reason, cold), `cot_output_cost` returns the extra per-call price, and you can defend each budget scenario.

# %% [markdown]
# [↑ Back to top](#top)
