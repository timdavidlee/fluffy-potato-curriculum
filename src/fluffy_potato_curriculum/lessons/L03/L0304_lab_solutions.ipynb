# %% [markdown]
# <a id="top"></a>
#
# # Lab L0304: write a chain-of-thought prompt
#
# ```yaml
# title: "Lab L0304: write a chain-of-thought prompt"
# keywords: chain-of-thought, cot, step by step, numbered scaffold, token cost, lab
# estimated duration: 30
# ```
#
# > **Lesson:** L03. See [objectives.md](../../../../docs/origin/lesson_roadmaps/L03/objectives.md). Solutions: `L0304_lab_solutions.ipynb`. Makes **live** Claude calls — set `ANTHROPIC_API_KEY` (copy `.env.example` to `.env`) before running. The model varies run to run.
# >
# > **After this lab you can:** trigger CoT three ways; compare an answer with and without a scaffold; reason about the token cost CoT adds.

# %% [markdown]
# ## Contents
#
# - [1. Setup](#1-setup)
# - [2. Problem 1 — Trigger CoT with 'let's think step by step'](#2-problem-1--trigger-cot-with-lets-think-step-by-step)
# - [3. Problem 2 — Trigger CoT with a numbered scaffold](#3-problem-2--trigger-cot-with-a-numbered-scaffold)
# - [4. Problem 3 — Which trigger for which task? (written)](#4-problem-3--which-trigger-for-which-task-written)
# - [5. Self-check](#5-self-check)

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# A live client and a `run` helper that returns the reply text and output-token count.

# %%
from fluffy_potato_curriculum.potato_llm import AnthropicClient, Message, PotatoLLMClient

# A multi-step problem the model is unreliable on zero-shot.
PROBLEM = (
    "A store sells pencils in packs of 12 and erasers in packs of 10. "
    "Maya buys 4 pencil packs and 3 eraser packs, then gives away 9 pencils "
    "and 5 erasers. How many items does she have left?"
)

client: PotatoLLMClient = AnthropicClient()


def run(prompt: str, *, max_tokens: int = 500) -> tuple[str, int]:
    """Return (reply_text, output_tokens) for a single user prompt."""
    reply = client.chat([Message.user(prompt)], max_tokens=max_tokens, temperature=0.0)
    return reply.text.strip(), reply.usage.output_tokens


print(f"setup ready (live client: {client.model})")

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 2. Problem 1 — Trigger CoT with 'let's think step by step'

# %% [markdown]
# Build two prompts from `PROBLEM`: one that asks for the answer only, and one that appends `Let's think step by step.` Run both and print each answer with its token count. (Expected final answer: 34.)

# %%
zero_shot_prompt = PROBLEM + " Answer with a single number only."
cot_prompt = PROBLEM + " Let's think step by step."

for label, prompt in [("zero-shot", zero_shot_prompt), ("CoT", cot_prompt)]:
    text, tokens = run(prompt)
    print(f"=== {label} ({tokens} output tokens) ===")
    print(text)
    print()

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 3. Problem 2 — Trigger CoT with a numbered scaffold

# %% [markdown]
# Write a prompt that names the steps explicitly — e.g. (1) count pencils bought, (2) count erasers bought, (3) subtract the give-aways, (4) total. Run it and compare the structure to Problem 1's free-form CoT.

# %%
scaffold_prompt = PROBLEM + (
    " Solve in this order: (1) total pencils bought, (2) total erasers bought, "
    "(3) subtract the 9 pencils and 5 erasers given away, (4) add the two remaining "
    "counts for the final total."
)
text, tokens = run(scaffold_prompt)
print(f"=== numbered scaffold ({tokens} output tokens) ===")
print(text)

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 4. Problem 3 — Which trigger for which task? (written)

# %% [markdown]
# For each task, write the CoT variant you'd reach for — `none`, `step-by-step`, `numbered`, or `worked-example` — and one phrase of justification.
#
# | Task | Variant | Why |
# | --- | --- | --- |
# | Classify a clearly-positive review's sentiment | _TODO_ | _TODO_ |
# | A 4-step word problem you must show work for | _TODO_ | _TODO_ |
# | Extract data into your team's idiosyncratic format | _TODO_ | _TODO_ |
# | A production prompt that must return the same shape every call | _TODO_ | _TODO_ |

# %% [markdown]
# _Write your answers by editing the table above (double-click the cell)._

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 5. Self-check

# %% [markdown]
# Compare against `L0304_lab_solutions.ipynb`. Done when both CoT prompts produce the right answer (34), you can see the numbered scaffold gives more consistent structure, and you can state the token-cost difference between zero-shot and CoT.

# %% [markdown]
# [↑ Back to top](#top)
