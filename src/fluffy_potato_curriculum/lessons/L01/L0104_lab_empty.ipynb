# %% [markdown]
# <a id="top"></a>
#
# # Lab L0104: tokenization
#
# ```yaml
# title: "Lab L0104: tokenization"
# keywords: tokens, tokenizer, tiktoken, chars per token, lab
# estimated duration: 30
# ```
#
# > **Lesson:** L01. See [objectives.md](../../../../docs/origin/lesson_roadmaps/L01/objectives.md). Solutions: `L0104_lab_solutions.ipynb`. Runs offline.
# >
# > **After this lab you can:** count tokens and see boundaries; predict when a string beats the ≈4-chars/token rule; show that tokenizers disagree.

# %% [markdown]
# ## Contents
#
# - [1. Setup](#1-setup)
# - [2. Problem 1 — Count tokens](#2-problem-1--count-tokens)
# - [3. Problem 2 — See the boundaries](#3-problem-2--see-the-boundaries)
# - [4. Problem 3 — Tokenizers disagree](#4-problem-3--tokenizers-disagree)
# - [5. Problem 4 — Where the rule of thumb breaks](#5-problem-4--where-the-rule-of-thumb-breaks)
# - [6. Self-check](#6-self-check)

# %% [markdown]
# ## 1. Setup

# %%
import tiktoken

SAMPLES = {
    "english": "The quick brown fox jumps over the lazy dog.",
    "code": "def f(x): return x ** 2",
    "json": '{"user_id": 12345, "events": ["click", "scroll"]}',
}
print("setup ready")

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 2. Problem 1 — Count tokens

# %% [markdown]
# Implement `count_tokens` with tiktoken's `cl100k_base`. Guess which sample is longest *before* running.

# %%
def count_tokens(text: str, encoding_name: str = "cl100k_base") -> int:
    enc = tiktoken.get_encoding(encoding_name)
    # TODO: return how many tokens enc produced for `text`.
    raise NotImplementedError("your code here")


for name, text in SAMPLES.items():
    print(name, "->", len(text), "chars")  # TODO: also print count_tokens(text)

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 3. Problem 2 — See the boundaries

# %% [markdown]
# Implement `show_boundaries`: decode each token on its own, join with `|`.

# %%
def show_boundaries(text: str, encoding_name: str = "cl100k_base") -> str:
    enc = tiktoken.get_encoding(encoding_name)
    # TODO: decode each token id separately, then join the pieces with "|".
    raise NotImplementedError("your code here")


print(show_boundaries(SAMPLES["code"]))

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 4. Problem 3 — Tokenizers disagree

# %% [markdown]
# Count each sample under `cl100k_base` and `o200k_base`. Then answer below: why does "how many tokens is this?" have no single universal answer?

# %%
for name, text in SAMPLES.items():
    cl = count_tokens(text, "cl100k_base")
    o2 = count_tokens(text, "o200k_base")
    print(f"{name:9} cl100k={cl:3}  o200k={o2:3}")

# %% [markdown]
# **Your answer:** _TODO — the count depends on which tokenizer; tokenizers are trained per model family, so there is no universal token count._

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 5. Problem 4 — Where the rule of thumb breaks

# %% [markdown]
# Compute chars-per-token for `english` and `json`. Which breaks the ≈4.0 rule, and why?

# %%
for name in ("english", "json"):
    text = SAMPLES[name]
    ratio = 0.0  # TODO: len(text) / count_tokens(text)
    print(f"{name:9} {ratio:.2f} chars/token")
# TODO (note): which breaks the ~4.0 rule, and why?

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 6. Self-check

# %% [markdown]
# No auto-grader — compare against `L0104_lab_solutions.ipynb`. Done when your counts match and you can explain why JSON is denser than English.

# %% [markdown]
# [↑ Back to top](#top)
