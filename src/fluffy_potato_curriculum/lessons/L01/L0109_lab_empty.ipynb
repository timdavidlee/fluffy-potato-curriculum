# %% [markdown]
# <a id="top"></a>
#
# # Lab L0109: temperature and sampling
#
# ```yaml
# title: "Lab L0109: temperature and sampling"
# keywords: temperature, sampling, variance, determinism, potato_llm seam, lab
# estimated duration: 30
# ```
#
# > **Lesson:** L01. See [objectives.md](../../../../docs/origin/lesson_roadmaps/L01/objectives.md). Solutions: `L0109_lab_solutions.ipynb`. Runs offline with a canned client; an optional cell makes real calls if `ANTHROPIC_API_KEY` is set.
# >
# > **After this lab you can:** observe how temperature changes spread; explain low-not-zero variance; pick a temperature for a task.

# %% [markdown]
# ## Contents
#
# - [1. Setup](#1-setup)
# - [2. Problem 1 — Sample at temperature 0](#2-problem-1--sample-at-temperature-0)
# - [3. Problem 2 — Sample at temperature 1](#3-problem-2--sample-at-temperature-1)
# - [4. Try it live (optional)](#4-try-it-live-optional)
# - [5. Problem 3 — Pick a temperature](#5-problem-3--pick-a-temperature)
# - [6. Problem 4 — Why isn't temperature 0 perfectly deterministic?](#6-problem-4--why-isnt-temperature-0-perfectly-deterministic)
# - [7. Self-check](#7-self-check)

# %% [markdown]
# ## 1. Setup
#
# A canned client keeps this lab deterministic. It matches the `PotatoLLMClient` shape, so the optional cell can swap in a real one.

# %%
import os

from fluffy_potato_curriculum.potato_llm import AnthropicClient, ChatResponse, Message, Usage


class CannedLLM:
    """An offline stand-in for a real client, so this notebook is deterministic.

    It fakes the *behavior* we want to observe: at low temperature it commits to one
    answer; at higher temperature it varies. Because it matches the `PotatoLLMClient`
    shape (a `model` and a `chat` method), the optional live cell can swap in a real
    `AnthropicClient` with no other changes.
    """

    model = "canned-sonnet"

    def __init__(self) -> None:
        self._varied = [
            "Rainy Day Roasters",
            "The Drizzle",
            "Petrichor Coffee",
            "Cloudbreak Beans",
            "Umbrella & Bean",
        ]
        self._calls = 0

    def chat(
        self,
        messages: list[Message],
        *,
        max_tokens: int = 1024,
        temperature: float = 1.0,
    ) -> ChatResponse:
        # Low temperature => sharp distribution => always the top choice.
        # Higher temperature => flatter => cycle through alternatives (deterministically).
        text = (
            self._varied[0] if temperature < 0.5 else self._varied[self._calls % len(self._varied)]
        )
        self._calls += 1
        return ChatResponse(
            text=text, model=self.model, usage=Usage(input_tokens=20, output_tokens=4), raw=None
        )


PROMPT = "Suggest a name for a coffee shop on a rainy street in Seattle. Just the name, one or two words."
print("setup ready (offline, canned client)")

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 2. Problem 1 — Sample at temperature 0

# %% [markdown]
# Write `sample_n(client, temperature, n)`: call `client.chat([Message.user(PROMPT)], max_tokens=16, temperature=temperature)` n times and collect the replies. Run 5x at 0.

# %%
def sample_n(client: CannedLLM, temperature: float, n: int) -> list[str]:
    # TODO: call client.chat(...) n times and collect reply.text for each.
    raise NotImplementedError("your code here")


client = CannedLLM()
for line in sample_n(client, 0.0, 5):
    print(line)

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 3. Problem 2 — Sample at temperature 1

# %% [markdown]
# Run the same prompt 5x at temperature 1. How does the spread compare?

# %%
for line in sample_n(client, 1.0, 5):  # TODO: confirm sample_n works at temperature=1.0
    print(line)

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 4. Try it live (optional)

# %% [markdown]
# Swap the canned client for a real one. Gated on `ANTHROPIC_API_KEY`; clear this cell's output before committing.

# %%
if os.environ.get("ANTHROPIC_API_KEY"):
    live = AnthropicClient()
    for line in sample_n(live, 1.0, 5):  # type: ignore[arg-type]  # AnthropicClient matches the seam
        print(line)
else:
    print("Set ANTHROPIC_API_KEY to run this live. (Skipped.)")

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 5. Problem 3 — Pick a temperature

# %% [markdown]
# For each task, fill in a temperature (low ≈ 0 or high ≈ 0.7–1.0) and one phrase of justification.
#
# | Task | Temperature | Why |
# | ---- | ----------- | --- |
# | Classify a support ticket into one of 5 categories | _TODO_ | _TODO_ |
# | Brainstorm 10 product names | _TODO_ | _TODO_ |
# | Extract a date from an invoice into JSON | _TODO_ | _TODO_ |
# | Route a request to the right tool (preview of L04) | _TODO_ | _TODO_ |

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 6. Problem 4 — Why isn't temperature 0 perfectly deterministic?

# %% [markdown]
# In 2–3 sentences, explain why `temperature=0` can still occasionally vary. Name one concrete cause.
#
# > _TODO: floating-point non-determinism, server-side batching, or tie-breaking between equally-likely tokens._

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 7. Self-check

# %% [markdown]
# Compare against `L0109_lab_solutions.ipynb`. Done when your temperature-1 runs are more varied than temperature-0, and you can explain low-vs-zero variance.

# %% [markdown]
# [↑ Back to top](#top)
