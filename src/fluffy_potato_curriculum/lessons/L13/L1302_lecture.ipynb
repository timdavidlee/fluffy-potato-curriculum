# %% [markdown]
# <a id="top"></a>
#
# # Build the eval harness — case, scorer, runner
#
# ```yaml
# title: "Build the eval harness — case, scorer, runner"
# keywords: evaluation, eval case, scorer, runner, outcome scoring, trajectory scoring, regression case, brittleness, Langfuse, dataset, upload_dataset, teacher lecture
# estimated duration: 40
# ```
#
# > **Lesson:** L13 Evaluation. Roadmap: [objectives.md](../../../../docs/origin/lesson_roadmaps/L13/objectives.md) (objectives 1 & 2), [demos_or_activities.md](../../../../docs/origin/lesson_roadmaps/L13/demos_or_activities.md) (Demos 1–2).
# >
# > **Concept first, then the platform** — the same move as L12's trace → Langfuse. Sections 1–3 build the case/scorer/runner concept **offline** on the scripted `FakeModel` (no API key). Section 4 then uploads the very same cases to the cohort's **live Langfuse** as a **Dataset**. That tooled cell soft-skips when Langfuse isn't configured, so a keyless run of this notebook still completes.

# %% [markdown]
# ## Contents
#
# - [1. Setup — runs to score](#1-setup--runs-to-score)
# - [2. The eval harness, made visible](#2-the-eval-harness-made-visible)
#   - [2.1 A case is an input plus what "good" means](#21-a-case-is-an-input-plus-what-good-means)
#   - [2.2 A scorer turns one run into a verdict](#22-a-scorer-turns-one-run-into-a-verdict)
#   - [2.3 The runner runs every case and reports](#23-the-runner-runs-every-case-and-reports)
#   - [2.4 Score the path, not only the answer](#24-score-the-path-not-only-the-answer)
# - [3. From a trace to a regression case](#3-from-a-trace-to-a-regression-case)
#   - [3.1 The runaway becomes a trajectory check](#31-the-runaway-becomes-a-trajectory-check)
#   - [3.2 The tool-error becomes an outcome check](#32-the-tool-error-becomes-an-outcome-check)
#   - [3.3 The brittleness beat](#33-the-brittleness-beat)
# - [4. Now go tooled: the cases as a Langfuse Dataset](#4-now-go-tooled-the-cases-as-a-langfuse-dataset)
#   - [4.1 Upload the eval set with the bridge](#41-upload-the-eval-set-with-the-bridge)
#   - [4.2 What you see in Langfuse](#42-what-you-see-in-langfuse)
# - [5. Takeaways](#5-takeaways)

# %% [markdown]
# ## 1. Setup — runs to score
#
# L12 produced the record (the trace); L13 **judges it**. To judge runs we first need runs. We drive the **same** `agent_graph.run(...)` from L10/L12 with a scripted `FakeModel`, so every run is deterministic and keyless — the focus stays on *eval design*, not on coaxing a live model.
#
# The new import is `fluffy_potato_curriculum.common.evals` — the eval harness this lesson is about. It is ~30 lines of plain Python you can read end-to-end; open `common/evals.py` alongside this notebook.
#
# A **`run_case`** is the thing under test: given a case, it produces one `RunResult`. Ours looks the case up in a script table and runs the graph. (Two `run_case`s over the same cases — one per model — is the A/B in the next lecture.)

# %%
from langchain_core.messages import AIMessage

from fluffy_potato_curriculum.common.agent_graph import RunResult, run
from fluffy_potato_curriculum.common.evals import (
    EvalCase,
    EvalResult,
    evaluate,
    tool_calls,
    tool_trajectory,
)
from fluffy_potato_curriculum.common.fake_model import (
    FakeModel,
    text_reply,
    tool_call,
    tool_reply,
)
from fluffy_potato_curriculum.common.tools import TOOLS

TASK_CHAIN = "What is 17 * 23, and what is the population of Tokyo?"

# A script table: case id -> the model's scripted moves for that case. A runaway is
# scripted as several *distinct* tool-call replies (see "atlantis_runaway" below):
# the graph's add_messages reducer keys on message id, so repeating one identical
# reply would be de-duplicated and the cycle would stop early instead of running away.
SCRIPTS: dict[str, list[AIMessage]] = {
    # clean two-tool run; the answer contains "37000000" (no commas) on purpose.
    "tokyo_pop": [
        tool_reply(tool_call("c1", "calculator", {"expression": "17*23"})),
        tool_reply(tool_call("c2", "lookup", {"city": "Tokyo"})),
        text_reply("17 * 23 is 391, and Tokyo has a population of 37000000."),
    ],
}


def run_case(case: EvalCase) -> RunResult:
    """Run the graph for one case using its scripted FakeModel (a fresh one each call).

    ``max_steps`` is read from the case inputs so a runaway case can cap low.
    """
    model = FakeModel(SCRIPTS[case.id])
    return run(model, TOOLS, case.inputs["task"], max_steps=case.inputs.get("max_steps", 8))


# One case, carrying BOTH an expected answer and an expected trajectory.
tokyo_case = EvalCase(
    id="tokyo_pop",
    inputs={"task": TASK_CHAIN},
    reference_outputs={"answer": "37000000", "expected_tools": ["calculator", "lookup"]},
)

demo_run = run_case(tokyo_case)
print("termination:", demo_run.termination, "| iterations:", demo_run.iterations)
print("final_text:", demo_run.final_text)
# Out:
# termination: natural | iterations: 3
# final_text: 17 * 23 is 391, and Tokyo has a population of 37000000.

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 2. The eval harness, made visible
#
# Three nouns and one verb, and you can read every one of them:
#
# - a **case** (`EvalCase`) — an input (`inputs`) plus what "good" means (`reference_outputs`);
# - a **scorer** (`Scorer`) — a function `(*, run, example) -> EvalResult` that turns one run into a verdict;
# - a **runner** (`evaluate`) — runs every case and reports a summary.
#
# The whole "framework" is a function from `(run, example)` to a verdict, called in a loop. Nothing magic.

# %% [markdown]
# ### 2.1 A case is an input plus what "good" means
#
# `EvalCase` is a typed record — like an L12 trace event. `inputs` seeds the run; `reference_outputs` is the answer key a scorer checks against. These field names line up with LangSmith's *Example* (`inputs` / `reference_outputs`), so they transfer if you adopt a platform later.

# %%
print("id:               ", tokyo_case.id)
print("inputs:           ", tokyo_case.inputs)
print("reference_outputs:", tokyo_case.reference_outputs)
# Out:
# id:                tokyo_pop
# inputs:            {'task': 'What is 17 * 23, and what is the population of Tokyo?'}
# reference_outputs: {'answer': '37000000', 'expected_tools': ['calculator', 'lookup']}

# %% [markdown]
# ### 2.2 A scorer turns one run into a verdict
#
# A scorer reads `run.final_text` for **outcome** scoring (did it get the right answer?). It returns an `EvalResult` — a `key` (the metric name), a `score` (pass/fail), and an optional `comment`. Here is the first scorer, `answer_correct`: does the final text contain the reference answer?

# %%
def answer_correct(*, run: RunResult, example: EvalCase) -> EvalResult:
    """Outcome scorer: did the final text contain the reference answer (a substring)?"""
    expected = str(example.reference_outputs["answer"])
    return EvalResult(
        key="answer_correct",
        score=expected in run.final_text,
        comment=f"looking for {expected!r}",
    )


verdict = answer_correct(run=demo_run, example=tokyo_case)
print(verdict)
# Out:
# key='answer_correct' score=True comment="looking for '37000000'"

# %% [markdown]
# ### 2.3 The runner runs every case and reports
#
# `evaluate(run_case, cases, scorers)` is the loop: for each case it calls `run_case(case)` to produce a run, applies every scorer, and rolls the verdicts up into a table. Each cell reads `passes/samples` — here `samples=1`, so it's `1/1` (pass) or `0/1` (fail). The `ALL` column is the samples where *every* scorer passed.

# %%
report = evaluate(run_case, [tokyo_case], [answer_correct])
print(report.table())
# Out:
# case       answer_correct  ALL
# tokyo_pop  1/1             1/1

# %% [markdown]
# ### 2.4 Score the path, not only the answer
#
# For an agent, *how* it got there matters: a right answer reached by a runaway, over-budget path is still a problem. A **trajectory** scorer reads `run.trace` (via `tool_trajectory`, which lists the ordered tool-call names) instead of `run.final_text`. That trace is exactly the L12 artifact — which is *why* L12 came first.
#
# Add `expected_tools` and re-run. Now the **same run is scored two ways**: did it get the right answer, *and* did it take the right path?

# %%
def expected_tools(*, run: RunResult, example: EvalCase) -> EvalResult:
    """Trajectory scorer: did the ordered tool calls match the reference path?"""
    expected = list(example.reference_outputs["expected_tools"])
    actual = tool_trajectory(run)
    return EvalResult(
        key="expected_tools",
        score=actual == expected,
        comment=f"{actual} vs expected {expected}",
    )


report = evaluate(run_case, [tokyo_case], [answer_correct, expected_tools])
print(report.table())
print()
print("trajectory was:", tool_trajectory(demo_run))
# Out:
# case       answer_correct  expected_tools  ALL
# tokyo_pop  1/1             1/1             1/1
#
# trajectory was: ['calculator', 'lookup']

# %% [markdown]
# An eval set can score the **answer**, the **path**, or **both**. Pick deliberately — for agents the path often matters as much as the answer.

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 3. From a trace to a regression case
#
# The most important rule in this lesson:
#
# > **trace a failure → write a case that catches it → keep the case forever.**
#
# Good eval cases come from *observed* failures, not imagination. L12 handed you four failure signatures — tool error, wrong arguments, runaway loop, premature termination. Each becomes a **regression case**: a check that **fails when the bug is present and passes when it's fixed**. A "case" that passes no matter what tests nothing.

# %% [markdown]
# ### 3.1 The runaway becomes a trajectory check
#
# Recall the L12 runaway signature in one line — *the same `(tool_name, args)` pair repeating, ending in `max_steps`*. We don't re-teach reading it; we turn it into a scorer. `no_runaway` reads `tool_calls` (names **with** args) and the termination cause, and fails if either red flag is present.
#
# We add two cases on the same Atlantis task: the broken one (runs away) and the fixed one (gives up cleanly). The check must fail on the first and pass on the second.

# %%
SCRIPTS["atlantis_runaway"] = [
    # distinct call ids (r0, r1, ...) keep add_messages from de-duping the repeats,
    # so lookup('Atlantis') fires each agent visit until max_steps caps it.
    tool_reply(tool_call(f"r{i}", "lookup", {"city": "Atlantis"}))
    for i in range(8)
]
SCRIPTS["atlantis_fixed"] = [
    # the "fixed" agent gives up cleanly with text only -> natural termination.
    text_reply("I do not have a population on file for Atlantis."),
]


def no_runaway(*, run: RunResult, example: EvalCase) -> EvalResult:
    """Trajectory scorer: no repeated (tool, args) call, and didn't hit the step cap."""
    calls = tool_calls(run)
    signatures = [(name, tuple(sorted(args.items()))) for name, args in calls]
    repeated = len(signatures) != len(set(signatures))
    hit_cap = run.termination == "max_steps"
    return EvalResult(
        key="no_runaway",
        score=not (repeated or hit_cap),
        comment=f"termination={run.termination}, tool_calls={len(calls)}",
    )


runaway_case = EvalCase(
    id="atlantis_runaway", inputs={"task": "Population of Atlantis?", "max_steps": 4}
)
fixed_case = EvalCase(id="atlantis_fixed", inputs={"task": "Population of Atlantis?"})

report = evaluate(run_case, [runaway_case, fixed_case], [no_runaway])
print(report.table())
# Out:
# case              no_runaway  ALL
# atlantis_runaway  0/1         0/1
# atlantis_fixed    1/1         1/1

# %% [markdown]
# `atlantis_runaway` scores `0/1` (the bug is present); `atlantis_fixed` scores `1/1` (the bug is gone). That is the definition of a regression case: **red when broken, green when fixed.**

# %% [markdown]
# ### 3.2 The tool-error becomes an outcome check
#
# The `flaky_fetch` tool fails in known ways (L12's raw material). `https://ok` returns a usable value; `https://crash` raises, and the `ToolNode` converts it to a `ToolMessage(status="error")`. A *good* run recovers the answer; a *broken* run gives up. An **outcome** check on the final text catches the difference — fails when the answer never recovered.

# %%
SCRIPTS["fetch_ok"] = [
    tool_reply(tool_call("c1", "flaky_fetch", {"url": "https://ok"})),
    text_reply("The page says: the answer is 42."),
]
SCRIPTS["fetch_crash"] = [
    tool_reply(tool_call("c1", "flaky_fetch", {"url": "https://crash"})),
    text_reply("Sorry, I could not fetch that URL."),  # gave up
]

fetch_ok_case = EvalCase(
    id="fetch_ok",
    inputs={"task": "Fetch https://ok and tell me the answer."},
    reference_outputs={"answer": "42"},
)
fetch_crash_case = EvalCase(
    id="fetch_crash",
    inputs={"task": "Fetch https://crash and tell me the answer."},
    reference_outputs={"answer": "42"},
)

report = evaluate(run_case, [fetch_ok_case, fetch_crash_case], [answer_correct])
print(report.table())
# Out:
# case         answer_correct  ALL
# fetch_ok     1/1             1/1
# fetch_crash  0/1             0/1

# %% [markdown]
# `fetch_ok` recovers the answer (`1/1`); `fetch_crash` gives up (`0/1`). Same scorer, two runs, one regression caught.

# %% [markdown]
# ### 3.3 The brittleness beat
#
# A check can be *too tight*. An exact/substring match on a number is fragile: a correct answer that's merely **reworded** trips it. A red that fires on a correct run is worse than no check — it trains you to ignore reds.
#
# Watch `answer_correct` fail on a run that is *right* but writes `37,000,000` with commas.

# %%
SCRIPTS["tokyo_reworded"] = [
    tool_reply(tool_call("c1", "calculator", {"expression": "17*23"})),
    tool_reply(tool_call("c2", "lookup", {"city": "Tokyo"})),
    # correct, but written with commas -> the substring "37000000" is NOT present.
    text_reply("17 x 23 = 391, and about 37,000,000 people live in Tokyo."),
]
reworded_case = EvalCase(
    id="tokyo_reworded",
    inputs={"task": TASK_CHAIN},
    reference_outputs={"answer": "37000000"},
)

print("strict substring check:")
print(evaluate(run_case, [reworded_case], [answer_correct]).table())
# Out:
# strict substring check:
# case            answer_correct  ALL
# tokyo_reworded  0/1             0/1

# %% [markdown]
# It reads `0/1` even though the answer is right. The fix is the **loosest check that still catches the bug** — here, normalize away commas and spaces before comparing. (When even a normalized check can't express the quality — "did the answer *acknowledge the failure gracefully*?" — you reach for an LLM-as-judge. We name that now and build a minimal one in `L1306_lecture`.)

# %%
def _digits_only(text: str) -> str:
    """Drop commas and spaces so '37,000,000' and '37000000' compare equal."""
    return text.replace(",", "").replace(" ", "")


def answer_correct_loose(*, run: RunResult, example: EvalCase) -> EvalResult:
    """Outcome scorer, loosened: compare with commas/spaces normalized out."""
    expected = str(example.reference_outputs["answer"])
    return EvalResult(
        key="answer_correct",
        score=_digits_only(expected) in _digits_only(run.final_text),
        comment="normalized digits",
    )


print("loosened check:")
print(evaluate(run_case, [reworded_case], [answer_correct_loose]).table())
# Out:
# loosened check:
# case            answer_correct  ALL
# tokyo_reworded  1/1             1/1

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 4. Now go tooled: the cases as a Langfuse Dataset
#
# You just built the concept by hand — a case, two scorers, a runner, and two regression cases — all in plain Python. *"That's the whole idea. A Langfuse experiment is this, hosted and durable."*
#
# Now do the real work in the tool. The eval set becomes a Langfuse **Dataset**, so it lives where every future run — a different model, a changed prompt, next week — can find it and be scored against it. This is the same **concept-first, then-tooled** move you saw in L12 (hand-built trace → Langfuse). Evaluation is where a platform pays off fastest, so from here on L13 lives in Langfuse.

# %% [markdown]
# ### 4.1 Upload the eval set with the bridge
#
# `common/evals.py` ships a two-function **Langfuse bridge** — `upload_dataset` and `emit_score`. `upload_dataset(client, cases, name=...)` creates a named Langfuse **Dataset** and adds one **dataset item** per case, mapping `case.inputs → input`, `case.reference_outputs → expected_output`, `case.id → item id`.
#
# The keys load through the config seam, never hard-coded: `require_langfuse()` returns `(host, public_key, secret_key)` — or raises a clear error if the cohort instance isn't configured. We gate on `langfuse_configured()` so this notebook still runs end-to-end without keys.

# %%
from fluffy_potato_curriculum.common.config import langfuse_configured, require_langfuse
from fluffy_potato_curriculum.common.evals import upload_dataset

# The eval set: the cases we built above, collected into ONE list. This same list
# is what `L1304_lecture` runs as an experiment and what the labs reuse.
DATASET_CASES = [
    tokyo_case,  # outcome + trajectory (the chaining task)
    fetch_ok_case,  # outcome: recovers a fetched value
    fetch_crash_case,  # outcome regression: must recover, not give up
    runaway_case,  # trajectory regression: no runaway
    reworded_case,  # brittleness: a correct-but-reworded answer
]
DATASET_NAME = "l13-agent-evals"

# Sections 1-3 ran OFFLINE. Uploading a dataset is the first TOOLED step, so it
# needs the cohort's live Langfuse. We soft-skip when it isn't configured so a
# keyless run of this notebook still finishes; in class the keys are set and this
# cell actually creates the dataset.
if langfuse_configured():
    from langfuse import Langfuse

    host, public_key, secret_key = require_langfuse()
    client = Langfuse(host=host, public_key=public_key, secret_key=secret_key)
    upload_dataset(
        client,
        DATASET_CASES,
        name=DATASET_NAME,
        description="L13 first-pass agent eval set (calculator / lookup / flaky_fetch).",
    )
    client.flush()
    print(f"uploaded {len(DATASET_CASES)} cases to Langfuse dataset {DATASET_NAME!r}")
else:
    print("Langfuse not configured — skipping the upload (the concept beat above still ran).")
    print(f"Would upload {len(DATASET_CASES)} cases as dataset {DATASET_NAME!r}:")
    for case in DATASET_CASES:
        print(f"  - {case.id}: expected_output={case.reference_outputs}")
# Out:
# Langfuse not configured — skipping the upload (the concept beat above still ran).
# Would upload 5 cases as dataset 'l13-agent-evals':
#   - tokyo_pop: expected_output={'answer': '37000000', 'expected_tools': ['calculator', 'lookup']}
#   - fetch_ok: expected_output={'answer': '42'}
#   - fetch_crash: expected_output={'answer': '42'}
#   - atlantis_runaway: expected_output={}
#   - tokyo_reworded: expected_output={'answer': '37000000'}

# %% [markdown]
# ### 4.2 What you see in Langfuse
#
# Open the Langfuse project and click into the **`l13-agent-evals`** dataset. Each case you built is now a **dataset item**: `case.inputs` is its `input`, `case.reference_outputs` is its `expected_output`, and `case.id` is the item id (so re-uploading *upserts* — it won't duplicate). This is the *same* list, now stored where every future run can find it.
#
# Nothing here is magic — a Dataset is a list of cases, exactly the list you wrote by hand. What the platform adds is **durability and comparison**: the next lecture runs this dataset as an **Experiment** (`L1304_lecture`), and `L1306_lecture` attaches **scores** — including a managed LLM-as-judge — to each run.
#
# > **Langfuse is a hard dependency from here on.** Unlike L12 (where the export was an optional payoff), L13's tooled cells *need* a live instance — there is no offline dataset. That is what `require_langfuse()` enforces: with the keys unset it raises a clear, actionable error (`"Langfuse is not configured: LANGFUSE_HOST, … not set."`) instead of failing deep in an SDK call. Dry-run the connection before class.

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 5. Takeaways
#
# - **Three nouns, one verb.** A **case** is an input plus what "good" means; a **scorer** turns one run into a verdict; the **runner** (`evaluate`) runs every case and reports. The harness is ~30 readable lines, not a framework — so nothing about the platform is magic.
# - **Score the answer, the path, or both.** Outcome scorers read `final_text`; trajectory scorers read `run.trace`. For agents the path often matters as much as the answer — which is why L12 (tracing) came first.
# - **Cases come from real failures.** **Trace a failure → write a case that catches it → keep it forever.** A regression case is red when broken and green when fixed; one that passes no matter what tests nothing.
# - **Use the loosest check that still catches the bug.** An over-tight check (exact string) trains you to ignore reds; escalate to a semantic/LLM-judge only when a cheap check genuinely can't express the quality.
# - **Then go tooled.** The same list of cases uploads to Langfuse as a **Dataset** (`upload_dataset`), where a case *is* a dataset item (`input` + `expected_output`). The platform doesn't change the idea — it makes it durable and comparable. Langfuse is a **hard dependency** from here (`require_langfuse()`).
# - **Next:** [`L1303_lab`](L1303_lab_empty.ipynb) — you write your own cases and scorers, including one regression case from an L12 failure, and upload your set as a Langfuse dataset. Then [`L1304_lecture`](L1304_lecture.ipynb) runs that dataset as two **Experiments** and confronts non-determinism, moving from a verdict to a **pass rate**.

# %% [markdown]
# [↑ Back to top](#top)
