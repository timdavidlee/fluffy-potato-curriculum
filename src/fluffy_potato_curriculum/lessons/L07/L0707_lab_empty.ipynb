# %% [markdown]
# <a id="top"></a>
#
# # Lab L0707: trace a tool-call round-trip
#
# ```yaml
# title: "Lab L0707: trace a tool-call round-trip"
# keywords: round-trip, four messages, tool_use, tool_result, call id, three outcomes, trace, lab
# estimated duration: 30
# ```
#
# > **Lesson:** L07. See [objectives.md](../../../../docs/origin/lesson_roadmaps/L07/objectives.md). Solutions: `L0707_lab_solutions.ipynb`. **Pure Python — no API key needed** (you dissect crafted transcripts, the same offline approach as the L0706 demo).
# >
# > **After this lab you can:** read a tool-call transcript message by message; match a `tool_result` to its `tool_use` by id; and tell the three observable outcomes apart.

# %% [markdown]
# ## Contents
#
# - [1. Setup](#1-setup)
# - [2. Problem 1 — Summarize each message's blocks](#2-problem-1--summarize-each-messages-blocks)
# - [3. Problem 2 — Match the result to the request by id](#3-problem-2--match-the-result-to-the-request-by-id)
# - [4. Problem 3 — Tell the three outcomes apart](#4-problem-3--tell-the-three-outcomes-apart)
# - [5. Problem 4 — Why four messages? (written)](#5-problem-4--why-four-messages-written)
# - [6. Self-check](#6-self-check)

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# A captured four-message transcript of one successful round-trip (roles and block types as the Anthropic SDK reports them).

# %%
CALL_ID = "toolu_01XYZ"
transcript: list[dict[str, object]] = [
    {"role": "user", "content": "What is 6,150 multiplied by 7,012?"},
    {
        "role": "assistant",
        "content": [
            {
                "type": "tool_use",
                "id": CALL_ID,
                "name": "calculator",
                "input": {"expression": "6150 * 7012"},
            }
        ],
    },
    {
        "role": "user",
        "content": [{"type": "tool_result", "tool_use_id": CALL_ID, "content": "43123800"}],
    },
    {"role": "assistant", "content": [{"type": "text", "text": "6,150 x 7,012 = 43,123,800."}]},
]
print(f"{len(transcript)} messages captured")

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 2. Problem 1 — Summarize each message's blocks

# %% [markdown]
# Implement `block_types(content)` returning a comma-joined list of the block `type`s in a message (or `"text"` when `content` is a plain string). Print one line per message: its role and its block types.

# %%
def block_types(content: object) -> str:
    # TODO: if content is a str return 'text'; else join the 'type' of each block.
    raise NotImplementedError("your code here")


for i, msg in enumerate(transcript, start=1):
    print(f"msg {i}: role={msg['role']:9} blocks={block_types(msg['content'])}")

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 3. Problem 2 — Match the result to the request by id

# %% [markdown]
# Implement `ids_match(transcript)`: pull the `tool_use` id from message 2 and the `tool_result`'s `tool_use_id` from message 3, and return whether they are equal. That id is what ties a result to the call it answers.

# %%
def ids_match(t: list[dict[str, object]]) -> bool:
    # TODO: compare t[1]'s tool_use 'id' with t[2]'s tool_result 'tool_use_id'.
    raise NotImplementedError("your code here")


print("ids match:", ids_match(transcript))  # expect True

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 4. Problem 3 — Tell the three outcomes apart

# %% [markdown]
# Handing a model a tool has three observable outcomes. Implement `classify(assistant_msg)` returning `"called"` (has a `tool_use` block), `"answered"` (only a `text` block), or `"malformed"` (has a `tool_use` block whose `input` is missing the `expression` key). Run it over the three crafted assistant messages.

# %%
CASES: dict[str, dict[str, object]] = {
    "A": {
        "role": "assistant",
        "content": [
            {"type": "tool_use", "id": "t1", "name": "calculator", "input": {"expression": "2*3"}}
        ],
    },
    "B": {"role": "assistant", "content": [{"type": "text", "text": "It is 6."}]},
    "C": {
        "role": "assistant",
        "content": [{"type": "tool_use", "id": "t2", "name": "calculator", "input": {}}],
    },
}


def classify(assistant_msg: dict[str, object]) -> str:
    # TODO: return 'called' / 'answered' / 'malformed' per the rules above.
    raise NotImplementedError("your code here")


for name, msg in CASES.items():
    print(name, "->", classify(msg))

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 5. Problem 4 — Why four messages? (written)

# %% [markdown]
# The user asked **once**, but a successful tool exchange is at least four messages. In a sentence or two: what are the four messages, and who produces each?
#
# _Write your answer by editing this cell (double-click)._
#
# _TODO_

# %% [markdown]
# [↑ Back to top](#top)

# %% [markdown]
# ## 6. Self-check

# %% [markdown]
# Compare against `L0707_lab_solutions.ipynb`. Done when `ids_match` is `True` and `classify` returns `called`, `answered`, `malformed` for A, B, C.

# %% [markdown]
# [↑ Back to top](#top)
